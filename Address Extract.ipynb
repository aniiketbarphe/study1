# %%
import pandas as pd
import numpy as np


df= pd.read_excel('Trial-Check-01102022.xlsx')

# %%
df
# Out:
#       policy_no  mail_location_cd  \
# 0    5130011004       10096928072
# 1    5130011030       10096931074
# 2    5130011041       10096929392
# 3    5130011086       10096967925
# 4    5160001785       10103912252
# ..          ...               ...
# 168  5160393366       10106327446
# 169  5160393372       10106328299
# 170  5182214448       10103912412
# 171  5182214747       10103912405
# 172  5182301882       10081545428
#
#                                           risk_address             Unique Key  \
# 0    (LAN 3394261000081) PROP: . K,G RAJAN RP X 241...  513001100410096928072
# 1    (LAN 3394261000017) TAAZA ENCLAVEOPP SBI,PERUM...  513001103010096931074
# 2    (LAN 3394261000017) V/547 M C,ROADMALAMURY,PER...  513001104110096929392
# 3    (LAN 3539261000161) DOOR NO 41/1011A,GROUND FL...  513001108610096967925
# 4    (LAN - 0713727019107'''') SY NO - 462/2,PAINGA...  516000178510103912252
# ..                                                 ...                    ...
# ...

# %%
df['address_line_1'].str.split(')',expand=True)[1].to_csv('address_line_1.csv',index=None,header=False)

# %%
df['address_line_1'].str.split(')',expand=True)[1].head(100)
# Out:
# 0                                PROP: . K
# 1                     TAAZA ENCLAVEOPP SBI
# 2                                V/547 M C
# 3                         DOOR NO 41/1011A
# 4                            SY NO - 462/2
#                       ...
# 95     SASTHA BUILDING ELAMKUNNAPUZHA VYPI
# 96                           KOCHUPARAMBIL
# 97      CHAMBER NO 544 KHCAA GOLDEN JUBILE
# 98               61/1936 KURUSHUPALLY ROAD
# 99                        3/68 MEPPARAMBIL
# Name: 1, Length: 100, dtype: object
